# %%
#TASK 1 (Private Constructor)
import math
class Circle:
  def __init__(self,radius):
    self.__radius = radius

  def getRadius(self):
    return self.__radius

  def setRadius(self,radius):
    self.__radius = radius
  def area (self):
    return  math.pi * (self.__radius ** 2)
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())

c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#TASK 2 (AREA OF TRIANGLE)---->
class Triangle:
  def __init__(self,base,height):
    self.__base = base
    self.__height = height

  def getBase(self):
    return self.__base
  def setBase(self,base):
    self.__base = base
  def getHeight(self):
    return self.__height
  def setHeight(self,height):
    self.__height = height
  def area(self):
    return 0.5*self.__base*self.__height

t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())

t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#TASK 3 (ONE PRIVATE CLASS AND ONE PUBLIC CLASS)
class Team: #Team class private
  def __init__(self,team_name = None):
    self.__team_name = team_name
    self.__player_list = []
  def setName(self,team_name):
    self.__team_name = team_name
  def addPlayer(self,player_name):
    self.__player_list.append(player_name.player_name)
  def printDetail(self):
    print("=====================")
    print("Team:", self.__team_name)
    print("List of Players:")
    print(self.__player_list)

    print("=====================")
class Player:
  def __init__(self,player_name):
    self.player_name = player_name
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of Players:
# ['Mashrafi', 'Tamim']
# ...
# Team: Australia
# List of Players:
# ['Ponting', 'Lee']
# ...

# %%
#TASK 4
class Spaceship:
  def __init__(self,name_of_spaceship, capacity):
    self.name_of_spaceship =  name_of_spaceship
    self.capacity          =  capacity
    self.cargo_weight      = 0
    self.cargo_name        = []
    self.last_cargo_weight = 0
    self.last_cargo_name   = []
  def load_cargo(self,cargoName_weight):
    # can_add = True
    # if can_add == True :
      if cargoName_weight.getWeight() <= self.capacity:
        self.cargo_weight += cargoName_weight.getWeight()
        self.cargo_name.append(cargoName_weight.getName())
      else:
        self.last_cargo_weight += cargoName_weight.getWeight()
        self.last_cargo_name.append(cargoName_weight.getName())
        print(f"Warning: Unable to load {self.last_cargo_name[0]} inside {self.name_of_spaceship}. Exceeds capacity by {(self.cargo_weight + self.last_cargo_weight)-self.capacity}.")
        # can_add = False
  def display_details(self):
    if len(self.last_cargo_name) == 0:
      print(f"Spaceship Name: {self.name_of_spaceship}")
      print(f"Capacity: {self.capacity}")
      print(f"Current Cargo Weight: {self.cargo_weight}" )
      print(f"Cargo: {self.cargo_name}")
    # else:
      # print(f"Warning: Unable to load {self.last_cargo_name[0]} inside {self.name_of_spaceship}. Exceeds capacity by {(self.cargo_name+self.last_cargo_weight)-self.capacity}.")
class Cargo:
  def __init__(self,name,weight):
    self.__name   = name
    self.__weight = weight
  def getName(self):
    return self.__name
  def getWeight(self):
    return self.__weight
# Creating spaceships
falcon = Spaceship("Falcon", 50000)
apollo = Spaceship("Apollo", 100000)
enterprise = Spaceship("Enterprise", 220000)
print("1.===================================")
# Creating cargo
gold = Cargo("Gold", 20000)
platinum = Cargo("Platinum", 25000)
dilithium = Cargo("Dilithium", 50000)
trilithium = Cargo("Trilithium", 70000)
neutronium = Cargo("Neutronium", 80000)
print("2.===================================")
# Loading cargo onto spaceships
falcon.load_cargo(gold)
falcon.load_cargo(platinum)
falcon.display_details()
print("3.===================================")
apollo.load_cargo(gold) # Apollo will not 2reach its total capacity
apollo.display_details()
print("4.===================================")
falcon.load_cargo(neutronium) # This should exceed Falcon's capacity
print("5.===================================")
enterprise.load_cargo(dilithium)
enterprise.load_cargo(trilithium)
enterprise.load_cargo(neutronium) # This should not exceed Enterprise's capacity
enterprise.display_details()
# Out:
# 1.===================================
# 2.===================================
# Spaceship Name: Falcon
# Capacity: 50000
# Current Cargo Weight: 45000
# Cargo: ['Gold', 'Platinum']
# 3.===================================
# Spaceship Name: Apollo
# Capacity: 100000
# Current Cargo Weight: 20000
# Cargo: ['Gold']
# 4.===================================
# ...
# 5.===================================
# Spaceship Name: Enterprise
# Capacity: 220000
# Current Cargo Weight: 200000
# Cargo: ['Dilithium', 'Trilithium', 'Neutronium']

# %%
#Task 5 (Brac University Bus ticket)
class BracuStudent:
  def __init__(self, passenger_name,home ):
    self.passenger_name = passenger_name
    self.home           = home
    self.getPass        = "False"
  def show_details(self):
    print(f"Student Name: {self.passenger_name}\nLives in {self.home}\nHave Bus Pass? {self.getPass}")
  def get_pass(self,getPass = None):
    if getPass == None:
      self.getPass = "True"
class BracuBus:
  def __init__(self,destination,capacity = 2):
    self.destination = destination
    self.capacity    = capacity
    self.passenger_list = []
  def board(self,*name_home):
    if len(name_home) == 0 :
      print("No passengers!")
    elif self.capacity > len(self.passenger_list):
      for BracuStudent_class in name_home :
          if (BracuStudent_class.home == self.destination) and (BracuStudent_class.getPass == "True")  :
            print(f"{BracuStudent_class.passenger_name} boarded the bus.")
            self.passenger_list.append(BracuStudent_class.passenger_name)
            if len(self.passenger_list) == self.capacity :
              print(f"Bus is full!")
              break
          if (BracuStudent_class.getPass != "True"):
            print("You don't have a bus pass!")
          if BracuStudent_class.home != self.destination :
            print("You got on the wrong bus!")
  def show_details(self):
    print(f"Bus Route: {self.destination}\nPassengers Count: {len(self.passenger_list)} (Max: {self.capacity})\nPassengers On Board: {self.passenger_list}")

st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? False
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? False
# 2===========================
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? False
# 3===========================
# Bus Route: Mirpur
# Passengers Count: 0 (Max: 2)
# Passengers On Board: []
# Bus Route: Azimpur
# Passengers Count: 0 (Max: 5)
# Passengers On Board: []
# 4===========================
# 5===========================
# Student Name: Shanto
# Lives in Motijheel
# Have Bus Pass? True
# Student Name: Taskin
# Lives in Mirpur
# Have Bus Pass? True
# 6===========================
# No passengers!
# 7===========================
# You don't have a bus pass!
# You got on the wrong bus!
# 8===========================
# Student Name: Afif
# Lives in Mirpur
# Have Bus Pass? True
# Student Name: Shanto
# Lives in Mirpur
# Have Bus Pass? True
# 9===========================
# Afif boarded the bus.
# ...

# %%
class BracuStudent:
    def __init__(self, passenger_name, home):
        self.passenger_name = passenger_name
        self.home = home
        self.getPass = False
    def show_details(self):
        if self.getPass == 'True':
          print(f"Student Name: {self.passenger_name}\nLives in {self.home}\nHave Bus Pass? {self.getPass}")
        else:
          print(f"Student Name: {self.passenger_name}\nLives in {self.home}\nHave Bus Pass? {self.getPass}")
    def get_pass(self):
        self.getPass = True
class BracuBus:
    def __init__(self, destination, capacity=2):
        self.destination = destination
        self.capacity = capacity
        self.passenger_list = []

    def board(self, *students):
        if len(students) == 0:
            print("No passengers!")
        else:
            for student in students:
                if len(self.passenger_list) < self.capacity :
                    if student.home == self.destination and student.getPass:
                        print(f"{student.passenger_name} boarded the bus.")
                        self.passenger_list.append(student.passenger_name)
                    elif not student.getPass:
                        print(f"you don't have a bus pass!")
                    else:
                        print(f"you got on the wrong bus!")
                else:
                    print("Bus is full!")

    def show_details(self):
        print(f"Bus Route: {self.destination}\nPassengers Count: {len(self.passenger_list)} (Max: {self.capacity})\nPassengers On Board: {self.passenger_list}")


st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()

# %%
#TASK 6 (Events occur in Library )
class Library:
    def __init__(self, l_name, l_dict):
        self.l_name = l_name
        self.l_dict = l_dict
        self.d = {}

    def details(self):
        print(f"{self.l_name} Library details\nBorrower details: {self.d}\nBooks availability: {self.l_dict}")

class Reader:
    def __init__(self, r_name):
        self.r_name = r_name
        self.count = 0
        self.r_dict = {}

    def borrow(self, obj, *args):
        for genre in args:
            if genre in obj.l_dict and obj.l_dict[genre] > 0:
                if self.count < 5:
                    self.count += 1
                    obj.l_dict[genre] -= 1
                    print(f"{genre} book is borrowed successfully.")
                    if genre not in self.r_dict:
                        self.r_dict[genre] = 1
                    else:
                        self.r_dict[genre] += 1
                else:
                    print("You cannot borrow more than 5 books.")
            else:
                print(f"{genre} books are not available at the moment.")

        obj.d[self.r_name] = self.count

    def readerInfo(self, genre=None):
        if genre is None:
            print(f"{self.r_name}, you have {self.count} book(s) with you.")
            for key in self.r_dict:
                print(f"Books on {key}: {self.r_dict[key]}")
        elif genre in self.r_dict:
            print(f"{self.r_name}, you have {self.r_dict[genre]} {genre} book(s) with you.")
        else:
            print(f"{self.r_name}, you have 0 {genre} book(s) with you.")

L1 = Library('Dhaka', {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15})
L1.details()
print("1----------------------")
r1 = Reader('Aladdin')
r1.borrow(L1, 'Arts', 'Fiction', 'Fiction', 'Politics')
print("2----------------------")
r1.borrow(L1, 'Politics', 'Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2 = Reader('Jasmine')
r2.borrow(L1, 'Politics', 'Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details: {}
# Books availability: {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed successfully.
# Fiction book is borrowed successfully.
# Fiction book is borrowed successfully.
# Politics book is borrowed successfully.
# 2----------------------
# Politics book is borrowed successfully.
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 5 book(s) with you.
# Books on Arts: 1
# Books on Fiction: 2
# Books on Politics: 2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details: {'Aladdin': 5}
# Books availability: {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics books are not available at the moment.
# Poetry book is borrowed successfully.
# 7----------------------
# ...
