# %%
#Task 1.0 (Customer)
class Customer:
  def __init__(self):
    self.amount = 0
    self.added_Customer = []
    print("Welcome to ABC Memorial Park")
  def buyTicket(self,name,age):
    self.name = name
    self.age  = age
    self.added_Customer.append(self.name)
    if len(self.added_Customer) < 4 :
      print(f"Successfully purchased a ticket for {self.name}!")
      if self.age > 10:
        self.amount += 100
      if 0 <= self.age <= 10 :
        self.amount += 50
    else:
      print("You can't buy more than 3 tickets")
      self.added_Customer.pop()

  def showDetails(self):

    print(f"Amount of tickets: {len(self.added_Customer)}\nTotal price: {self.amount} Taka")
print('1-------------------------')
customer1 = Customer()
print('2-------------------------')
customer1.buyTicket('Bob', 23)
customer1.buyTicket('Henry', 7)
customer1.buyTicket('Alexa', 30)
customer1.buyTicket('Jonas', 43)
print('3-------------------------')
customer1.showDetails()
print('4-------------------------')
customer2 = Customer()
print('5-------------------------')
customer2.buyTicket('Harry', 60)
customer2.buyTicket('Tomas', 28)
print('6-------------------------')
customer2.showDetails()
# Out:
# 1-------------------------
# Welcome to ABC Memorial Park
# 2-------------------------
# Successfully purchased a ticket for Bob!
# Successfully purchased a ticket for Henry!
# Successfully purchased a ticket for Alexa!
# You can't buy more than 3 tickets
# 3-------------------------
# Amount of tickets: 3
# Total price: 250 Taka
# 4-------------------------
# Welcome to ABC Memorial Park
# 5-------------------------
# Successfully purchased a ticket for Harry!
# Successfully purchased a ticket for Tomas!
# 6-------------------------
# Amount of tickets: 2
# Total price: 200 Taka

# %%
#TASK - 1.1  (Customer)
class Customer:
  def __init__ (self):
    print("Welcome to ABC Memorial Park ")
    self.namelis t = []
    self.agelist = []
    self.uniq_name_list = []
    self.uniq_age_list  = []

  def buyTicket (self,name,age):
    self.name = name
    self.age  = age
    self.namelist.append(self.name)
    self.agelist.append(self.age)

    if len(self.namelist) < 4 :
      for i in range (len(self.namelist)):
        if i > 3 :
            break
        else:
          if self.namelist[i] not in self.uniq_name_list :
            self.uniq_name_list.append(self.namelist[i])
            print(f"Successfully purchased a ticket for {self.namelist[i]}!")
          else:
            pass
    if len(self.agelist) < 4 :
      for i in range (len(self.agelist)):
        if i > 3 :
            break
        else:
          if self.agelist[i] not in self.uniq_age_list :
            self.uniq_age_list.append(self.agelist[i])

    else:
      print("You can't buy more than 3 tickets")

  def showDetails(self):
    sum = 0
    for i in self.uniq_age_list:
      if 0 <= i <= 10 :
        sum += 50
      else:
        sum +=100
    print(f"Amount of tickets: {len(self.uniq_age_list)}")
    print(f"Total price: {sum} Taka ")

print('1-------------------------')
customer1 = Customer()
print('2-------------------------')
customer1.buyTicket('Bob', 23)
customer1.buyTicket('Henry', 7)
customer1.buyTicket('Alexa', 30)
customer1.buyTicket('Jonas', 43)
print('3-------------------------')
customer1.showDetails()
print('4-------------------------')
customer2 = Customer()
print('5-------------------------')
customer2.buyTicket('Harry', 60)
customer2.buyTicket('Tomas', 28)
print('6-------------------------')
customer2.showDetails()
# Out:
# 1-------------------------
# Welcome to ABC Memorial Park
# 2-------------------------
# Successfully purchased a ticket for Bob!
# Successfully purchased a ticket for Henry!
# Successfully purchased a ticket for Alexa!
# You can't buy more than 3 tickets
# 3-------------------------
# Amount of tickets: 3
# Total price: 250 Taka
# 4-------------------------
# Welcome to ABC Memorial Park
# 5-------------------------
# Successfully purchased a ticket for Harry!
# Successfully purchased a ticket for Tomas!
# 6-------------------------
# Amount of tickets: 2
# Total price: 200 Taka

# %%
#TASK - 1.2  (Customer)
class Customer:
  def __init__ (self):
    print("Welcome to ABC Memorial Park ")
    self.namelist = []
    self.number = 0
    self.amount = 0

  def buyTicket (self,name,age):
    self.name = name
    self.age  = age
    if self.number <= 3 :
        self.number += 1
        print(f"Successfully purchased a ticket for {self.name}!")
        if self.age > 10 :
          self.amount += 100
        else:
          self.amount += 50
    else :
          print("You can't buy more than 3 tickets")

  def showDetails(self):
    print(f"Amount of tickets: {self.number}")
    print(f"Total price: {self.amount} Taka ")

print('1-------------------------')
customer1 = Customer()
print('2-------------------------')
customer1.buyTicket('Bob', 23)
customer1.buyTicket('Henry', 7)
customer1.buyTicket('Alexa', 30)
customer1.buyTicket('Jonas', 43)
print('3-------------------------')
customer1.showDetails()
print('4-------------------------')
customer2 = Customer()
print('5-------------------------')
customer2.buyTicket('Harry', 60)
customer2.buyTicket('Tomas', 28)
print('6-------------------------')
customer2.showDetails()
# Out:
# 1-------------------------
# Welcome to ABC Memorial Park
# 2-------------------------
# Successfully purchased a ticket for Bob!
# Successfully purchased a ticket for Henry!
# Successfully purchased a ticket for Alexa!
# Successfully purchased a ticket for Jonas!
# 3-------------------------
# Amount of tickets: 4
# Total price: 350 Taka
# 4-------------------------
# Welcome to ABC Memorial Park
# 5-------------------------
# Successfully purchased a ticket for Harry!
# Successfully purchased a ticket for Tomas!
# 6-------------------------
# Amount of tickets: 2
# Total price: 200 Taka

# %%
#TASK - 2 Panda Care
class Panda:
  def __init__(self,name,gender,age):
    self.name   = name
    self.gender = gender
    self.age    = age
  def sleep(self,sleep_time):
    self.sleep_time = sleep_time
    if 3 <= self.sleep_time <= 5 :
       return(f"{self.name} sleeps {self.sleep_time} hours daily and should have Mixed Veggies. ")
    elif 6 <= self.sleep_time <= 8 :
       return(f"{self.name} sleeps {self.sleep_time} hours daily and should have Eggplant & Tofu. ")
    elif 9 <= self.sleep_time <= 11 :
      return(f"{self.name} sleeps {self.sleep_time} hours daily and should have Broccoli Chicken. ")
    else:
       return(f"{self.name} sleeps {self.sleep_time} hours daily and should have bamboo leaves. ")


panda1 = Panda("Kunfu", "Male", 5)
panda2 = Panda("Pan Pan", "Female",3)
panda3 = Panda("Ming Ming", "Female",8)

print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))

print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))

print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep(13))
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken.
# Kunfu sleeps 4 hours daily and should have Mixed Veggies.
# Ming Ming sleeps 13 hours daily and should have bamboo leaves.

# %%
#TASK - 3 (Updating)
class GreenPhone:
  def __init__(self,model,version, cameras):
    self.model = model
    self.version = version
    self.cameras = cameras

  def showSpecification(self):
    print(f"Phone Company: GreenPhone\nModel Name: {self.model}\nAndroid Version: {self.version}\nNumber of Cameras: {self.cameras}")


  def updatePhone(self):
    flgA = True
    flgA_count = 0
    flgM = True
    flgM_count = 0
    flgU = True
    flgU_count = 0
    if self.model[0] == "A" and flgA == True:
      self.version += 1
      print(f"Your phone Greenphone {self.model} is upgraded to Android Version: {self.version}.")
      flgA_count +=1
      if flgA_count == 2 :
        flgA = False
        if flgA == False :
          print(f"Your phone Greenphone {self.model} is already up todate.")



    elif self.model[0] == "M" and flgM == True:
      self.version += 1
      print(f"Your phone Greenphone {self.model} is upgraded to Android Version: {self.version}.")
      flgM_count +=1
      if flgM_count == 3 :
        flgM = False
        if flgM == False :
          print(f"Your phone Greenphone {self.model} is already up todate.")


    elif self.model[0] == "U" and flgU == True:
      self.version += 1
      print(f"Your phone Greenphone {self.model} is upgraded to Android Version: {self.version}.")
      flgU_count +=1
      if flgU_count == 4 :
        flgU = False
        if flgU == False :
          print(f"Your phone Greenphone {self.model} is already up todate.")

print('1=======================')
p1 = GreenPhone('A1', 12, 3)
p2 = GreenPhone('M11', 12, 4)
p3 = GreenPhone('U20', 12, 5)
p1.showSpecification()
print('2=======================')
p2.showSpecification()
print('3=======================')
p1.updatePhone()
print('4=======================')
p1.updatePhone()
p2.updatePhone()
p3.updatePhone()
print('5=======================')
p1.updatePhone()
p2.updatePhone()
p3.updatePhone()
print('6=======================')
p2.updatePhone()
p3.updatePhone()
print('7=======================')
p1.showSpecification()
p3.showSpecification()
# Out:
# 1=======================
# Phone Company: GreenPhone
# Model Name: A1
# Android Version: 12
# Number of Cameras: 3
# 2=======================
# Phone Company: GreenPhone
# Model Name: M11
# Android Version: 12
# Number of Cameras: 4
# 3=======================
# Your phone Greenphone A1 is upgraded to Android Version: 13.
# 4=======================
# Your phone Greenphone A1 is upgraded to Android Version: 14.
# Your phone Greenphone M11 is upgraded to Android Version: 13.
# Your phone Greenphone U20 is upgraded to Android Version: 13.
# 5=======================
# Your phone Greenphone A1 is upgraded to Android Version: 15.
# Your phone Greenphone M11 is upgraded to Android Version: 14.
# Your phone Greenphone U20 is upgraded to Android Version: 14.
# 6=======================
# Your phone Greenphone M11 is upgraded to Android Version: 15.
# Your phone Greenphone U20 is upgraded to Android Version: 15.
# 7=======================
# Phone Company: GreenPhone
# Model Name: A1
# ...

# %%
#TASK - 4 Student file
import math
class StudentDatabase:
  def __init__(self,name,id):
    self.name = name
    self.id   = id

    self.grades  = {}
  def calculateGPA(self,courses_cgpa,semester):
    self.semester = semester
    course = []
    cgpa=[]
    for i in courses_cgpa:
      courses = i.split(": ")
      course.append(courses[0])
      cgpa.append(float(courses[1]))
    sum = 0
    final_cgpa = 0
    for i in cgpa:
      sum += (i*3)
    final_cgpa = sum / (len(course)*3)
    self.grades.update({semester:{tuple(course):round(final_cgpa,2)}})
  def printDetails(self):

    print(f"Name: {self.name}\nID: {self.id}")
    for key , val in self.grades.items():
      print(f"Courses taken in {key}:")
      for  key1 , val1 in val.items():
        for i in key1 :
          print(i)
        print("CGPA:",val1)


s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0','MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'],'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('---------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7','ENG101: 4.0'], 'Summer2022')
print('---------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('---------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ---------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# CGPA: 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# CGPA: 3.85
# ---------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ---------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# CGPA: 3.8
