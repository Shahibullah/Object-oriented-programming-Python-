# %%
#Task 1
def bmi(a,b):
  h=a/100
  w=b
  d=round((w/h**2),1)
  if d<18.5:
    return(f"Score is {d}. You are Underweight")
  elif 18.5<=d<=24.9:
     return(f"Score is {d}. You are Normal")
  elif 25<=d<=30:
    return(f"Score is {d}. You are Overweight ")
  elif d>30:
    return(f"Score is {d}. You are Obese")
bmi(a=int(input("height :")),b=int(input("weight(cm) :")))
# Out:
# height :175
# weight(cm) :96
# 'Score is 31.3. You are Obese'

# %%
#Task 2
def food(a,b="Mohakhali"):
  arr=[250,170,200]
  meal_cost=0
  if a=="BBQ Chicken Cheese Burger":
    meal_cost+=arr[0]
  elif a=="Beef Burger":
    meal_cost+=arr[1]
  elif a=="Naga Drums":
    meal_cost+=arr[2]
  meal_cost+=meal_cost*.08
  if b=="Mohakhali":
    meal_cost+=40
  else:
    meal_cost+=60
  print(meal_cost)
food(a = input("Name of item :") , b = input("Place :"))
#Beef Burger" "Dhanmondi"
# Out:
# Name of item :Beef Burger
# Place :Dhanmondi
# 243.6

# %%
#Task 4
print("Checks whether a given string is a palindrome or not.")
def Palindrome(a):
  a=a.lower()
  temp = ""
  for i in a :
    if i != " " :
      temp += i
  i=0
  j=len(temp)-1
  while i<=j:
    if temp[i]!=temp[j]:
      b="Not a Palindrome"
      break
    else:
      b="Palindrome"
    i+=1
    j-=1
  print(b)
Palindrome(a=input("Enter the string :"))
# Out:
# Checks whether a given string is a palindrome or not.
# Enter the string :hello
# Not a Palindrome

# %%
""#Task 6
def herry(c):
  b=''
  for i in range(len(c)):
    if i==0:
      b+=c[i].upper()
    elif i==1:
      b+=c[i].lower()
    elif c[i-2]=="." or c[i-2] =="?":
       b+=c[(i)].upper()
    elif c[i] == "i":
      if c[i-1] == " " and c[i+1] == " ":
        b+=c[i].upper()
    else:
       b+=c[i]
  print(b)
herry('my favourite animal is a dog. a dog has sharp teeth so that it can eat flesh very easily. do you know my pet dog’s name? i love my pet very much.')
# Out:
# My favourte I anmal s a dog. A dog has sharp teeth so that t can eat flesh very easly. Do you know my pet dog’s name? I love my pet very much.

# %%
def replace_domain(email,domain,old_domain = "kaaj.com"):

  inputy = email.split("@")
  # print(inputy)
  # for i in range(len(inputx)):
  temp = ""
  if inputy[1] == inputx[2]:
    temp = "Changed: "+ inputy[0] + "@" +inputx[1]
    print(temp)
  # elif inputy[1] == inputx[1]:
  else:
    temp = "Unhanged: " + inputx[0]
    print(temp)
replace_domain("alice@sheba.xyz","sheba.xyx","kaaj.com")
# Out:
# ['alice', 'sheba.xyz']
# Unhanged: alice@sheba.xyz

# %%
DICT1 = {1 : "a"}
DICT2 = {2: "b"}
print(DICT1 | DICT2 )
# Out:
# {1: 'a', 2: 'b'}
